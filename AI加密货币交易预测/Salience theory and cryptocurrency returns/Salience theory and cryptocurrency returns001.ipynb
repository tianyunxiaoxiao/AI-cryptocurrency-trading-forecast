# %%
import pandas as pd
import numpy as np

# %%
import pandas as pd

# 检查并输入正确的文件路径
file_path = '/Users/a1/Desktop/future0_001.csv'  # 修改为正确的文件路径

try:
    merged_data = pd.read_csv(file_path)
    print("File loaded successfully.")
except FileNotFoundError as e:
    print(f"File not found: {e}")
# Out:
# File loaded successfully.

# %%
merged_data
# Out:
#                        open_time      open      high       low     close  \
# 0       2023-04-05T00:00:00.000Z  0.004807  0.004878  0.004545  0.004668
# 1       2023-04-06T00:00:00.000Z  0.004668  0.004683  0.004465  0.004538
# 2       2023-04-07T00:00:00.000Z  0.004540  0.004570  0.004351  0.004416
# 3       2023-04-08T00:00:00.000Z  0.004416  0.004589  0.004228  0.004265
# 4       2023-04-09T00:00:00.000Z  0.004266  0.004327  0.004087  0.004224
# ...                          ...       ...       ...       ...       ...
# 126505  2024-09-21T00:00:00.000Z  0.130500  0.132700  0.128300  0.132200
# 126506  2024-09-22T00:00:00.000Z  0.132300  0.132300  0.122600  0.126700
# 126507  2024-09-23T00:00:00.000Z  0.126800  0.132100  0.124000  0.131100
# 126508  2024-09-24T00:00:00.000Z  0.131100  0.137600  0.129200  0.136600
# 126509  2024-09-25T00:00:00.000Z  0.136600  0.138500  0.135600  0.138300
#
#               volume    close_time  quote_volume    count  taker_buy_volume  \
# 0       2.345775e+09  1.680739e+12  1.106453e+07  86650.0      1.105395e+09
# 1       1.740994e+09  1.680826e+12  7.900023e+06  68725.0      8.329836e+08
# 2       1.578476e+09  1.680912e+12  6.993093e+06  57472.0      7.815634e+08
# 3       3.125761e+09  1.680998e+12  1.371890e+07  89520.0      1.486423e+09
# 4       2.016344e+09  1.681085e+12  8.474897e+06  73047.0      9.809776e+08
# ...              ...           ...           ...      ...               ...
# 126505  4.512135e+07  1.726963e+12  5.886398e+06  32808.0      2.113208e+07
# 126506  4.706448e+07  1.727050e+12  5.986429e+06  38344.0      2.138675e+07
# 126507  4.465155e+07  1.727136e+12  5.792495e+06  38808.0      2.208139e+07
# 126508  7.888537e+07  1.727222e+12  1.063454e+07  51199.0      3.871896e+07
# 126509  3.313759e+06  1.727309e+12  4.529117e+05   2206.0      1.938562e+06
#
#         taker_buy_quote_volume  ignore futureStk        date           re1  \
# 0                 5.213880e+06     NaN   CKBUSDT  2023-04-05  2.550818e+08
# 1                 3.780752e+06     NaN   CKBUSDT  2023-04-06 -2.784919e-02
# 2                 3.463458e+06     NaN   CKBUSDT  2023-04-07 -2.688409e-02
# 3                 6.528667e+06     NaN   CKBUSDT  2023-04-08 -3.419384e-02
# 4                 4.125014e+06     NaN   CKBUSDT  2023-04-09 -9.613130e-03
# ...                        ...     ...       ...         ...           ...
# 126505            2.758921e+06     NaN   C98USDT  2024-09-21  1.302682e-02
# 126506            2.719144e+06     NaN   C98USDT  2024-09-22 -4.160363e-02
# 126507            2.864907e+06     NaN   C98USDT  2024-09-23  3.472770e-02
# 126508            5.220245e+06     NaN   C98USDT  2024-09-24  4.195271e-02
# 126509            2.652586e+05     NaN   C98USDT  2024-09-25  1.244510e-02
#
#              reDaily      reDaily7     reDaily30
# 0      -2.784919e-02 -6.255356e-02 -1.945159e-01
# 1      -2.688409e-02 -2.071397e-02 -2.148524e-01
# 2      -3.419384e-02  4.189312e-02 -1.886322e-01
# 3      -9.613130e-03  7.033998e-02 -2.808910e-01
# 4       5.397727e-02  1.373106e-01 -2.289299e-01
# ...              ...           ...           ...
# 126505 -4.160363e-02  7.976745e+06  7.976745e+06
# 126506  3.472770e-02  7.976745e+06  7.976745e+06
# 126507  4.195271e-02  7.976745e+06  7.976745e+06
# 126508  1.244510e-02  1.218107e+07  1.218107e+07
# 126509  6.550668e+06  6.550668e+06  6.550668e+06
#
# [126510 rows x 18 columns]

# %%
print(merged_data.columns)
# Out:
# Index(['open_time', 'open', 'high', 'low', 'close', 'volume', 'close_time',
#        'quote_volume', 'count', 'taker_buy_volume', 'taker_buy_quote_volume',
#        'ignore', 'futureStk', 'date', 're1', 'reDaily', 'reDaily7',
#        'reDaily30'],
#       dtype='object')

# %% [markdown]
# 复刻这篇论文的代码框架需要涵盖数据收集、数据处理、模型构建以及结果分析。由于论文主要围绕”Salience Theory”的资产定价模型，针对加密货币市场的实证研究，因此代码框架应包括以下几部分：
#
# 	1.	数据获取与预处理：
# 	•	从Coinmarketcap等网站获取加密货币的价格数据、交易量、市场资本化等基本信息。
# 	•	构造并处理数据，包括计算收益率、标准化数据、处理缺失值和异常值等。
# 	2.	Salience Measure 计算：
# 	•	使用论文中的公式(公式1, 2, 3)来计算每个加密货币的Salience Measure。通过每日回报率与市场平均回报率的差异来定义Salience。
# 	3.	Portfolio Sorting：
# 	•	根据计算出的Salience值，将加密货币按Salience Measure分组（五分位数分组）。
# 	•	计算等权重和市值加权组合的回报率，并生成Salience高低组合差策略。
# 	4.	实证回归与统计分析：
# 	•	使用回归模型来分析Salience Measure在加密货币市场中的表现。
# 	•	包括单一和双重排序的分析框架，以及Fama-MacBeth回归分析。
# 	5.	结果展示与可视化：
# 	•	生成统计表格与图表，展示结果的经济和统计意义。
# 	•	实现论文中的表格和图表，并根据回归模型输出结果。

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.tree import DecisionTreeRegressor

# 计算每日收益率 'reDaily' (收益率可以使用收盘价计算)
merged_data['daily_return'] = merged_data['close'].pct_change()

# 标准化 reDaily 列
scaler = StandardScaler()
merged_data['reDaily_scaled'] = scaler.fit_transform(merged_data[['reDaily']])

# 准备决策树模型的特征集
# 可以用相关的列来预测缺失值或者异常值
features = ['open', 'high', 'low', 'close', 'volume']  # 根据需要选择合适的特征

# 处理缺失值：使用决策树预测来填补缺失值
def fill_missing_with_tree(df, target_column, feature_columns):
    # 分离有缺失值和无缺失值的部分
    non_missing_data = df[df[target_column].notna()]
    missing_data = df[df[target_column].isna()]
    
    if missing_data.empty:
        return df  # 没有缺失值则不需要填补
    
    # 用无缺失值的数据训练决策树模型
    reg = DecisionTreeRegressor()
    reg.fit(non_missing_data[feature_columns], non_missing_data[target_column])
    
    # 预测缺失值
    df.loc[df[target_column].isna(), target_column] = reg.predict(missing_data[feature_columns])
    
    return df

# 对 daily_return 列进行缺失值填补
merged_data = fill_missing_with_tree(merged_data, 'daily_return', features)

# 异常值处理：我们使用 Z 分数来检测异常值
merged_data['z_score'] = np.abs(merged_data['daily_return'] - merged_data['daily_return'].mean()) / merged_data['daily_return'].std()

# 获取异常值的索引（例如 Z 分数超过 3 的为异常值）
outliers_index = merged_data[merged_data['z_score'] > 3].index

# 用决策树预测异常值
def replace_outliers_with_tree(df, target_column, feature_columns, outliers_index):
    # 分离正常值和异常值
    normal_data = df.drop(outliers_index)
    outliers_data = df.loc[outliers_index]
    
    if outliers_data.empty:
        return df  # 没有异常值则不需要替换
    
    # 用正常值的数据训练决策树模型
    reg = DecisionTreeRegressor()
    reg.fit(normal_data[feature_columns], normal_data[target_column])
    
    # 预测并替换异常值
    df.loc[outliers_index, target_column] = reg.predict(outliers_data[feature_columns])
    
    return df

# 替换异常值
merged_data = replace_outliers_with_tree(merged_data, 'daily_return', features, outliers_index)

# 删除临时 z_score 列
merged_data.drop(columns=['z_score'], inplace=True)

# 输出处理后的数据
print(merged_data[['date', 'daily_return', 'reDaily_scaled']].head())
# Out:
#          date  daily_return  reDaily_scaled
# 0  2023-04-05     -0.018750       -0.035613
# 1  2023-04-06     -0.027849       -0.035613
# 2  2023-04-07     -0.026884       -0.035613
# 3  2023-04-08     -0.034194       -0.035613
# 4  2023-04-09     -0.009613       -0.035613

# %%
merged_data
# Out:
#                        open_time      open      high       low     close  \
# 0       2023-04-05T00:00:00.000Z  0.004807  0.004878  0.004545  0.004668
# 1       2023-04-06T00:00:00.000Z  0.004668  0.004683  0.004465  0.004538
# 2       2023-04-07T00:00:00.000Z  0.004540  0.004570  0.004351  0.004416
# 3       2023-04-08T00:00:00.000Z  0.004416  0.004589  0.004228  0.004265
# 4       2023-04-09T00:00:00.000Z  0.004266  0.004327  0.004087  0.004224
# ...                          ...       ...       ...       ...       ...
# 126505  2024-09-21T00:00:00.000Z  0.130500  0.132700  0.128300  0.132200
# 126506  2024-09-22T00:00:00.000Z  0.132300  0.132300  0.122600  0.126700
# 126507  2024-09-23T00:00:00.000Z  0.126800  0.132100  0.124000  0.131100
# 126508  2024-09-24T00:00:00.000Z  0.131100  0.137600  0.129200  0.136600
# 126509  2024-09-25T00:00:00.000Z  0.136600  0.138500  0.135600  0.138300
#
#               volume    close_time  quote_volume    count  taker_buy_volume  \
# 0       2.345775e+09  1.680739e+12  1.106453e+07  86650.0      1.105395e+09
# 1       1.740994e+09  1.680826e+12  7.900023e+06  68725.0      8.329836e+08
# 2       1.578476e+09  1.680912e+12  6.993093e+06  57472.0      7.815634e+08
# 3       3.125761e+09  1.680998e+12  1.371890e+07  89520.0      1.486423e+09
# 4       2.016344e+09  1.681085e+12  8.474897e+06  73047.0      9.809776e+08
# ...              ...           ...           ...      ...               ...
# 126505  4.512135e+07  1.726963e+12  5.886398e+06  32808.0      2.113208e+07
# 126506  4.706448e+07  1.727050e+12  5.986429e+06  38344.0      2.138675e+07
# 126507  4.465155e+07  1.727136e+12  5.792495e+06  38808.0      2.208139e+07
# 126508  7.888537e+07  1.727222e+12  1.063454e+07  51199.0      3.871896e+07
# 126509  3.313759e+06  1.727309e+12  4.529117e+05   2206.0      1.938562e+06
#
#         taker_buy_quote_volume  ignore futureStk        date           re1  \
# 0                 5.213880e+06     NaN   CKBUSDT  2023-04-05  2.550818e+08
# 1                 3.780752e+06     NaN   CKBUSDT  2023-04-06 -2.784919e-02
# 2                 3.463458e+06     NaN   CKBUSDT  2023-04-07 -2.688409e-02
# 3                 6.528667e+06     NaN   CKBUSDT  2023-04-08 -3.419384e-02
# 4                 4.125014e+06     NaN   CKBUSDT  2023-04-09 -9.613130e-03
# ...                        ...     ...       ...         ...           ...
# 126505            2.758921e+06     NaN   C98USDT  2024-09-21  1.302682e-02
# 126506            2.719144e+06     NaN   C98USDT  2024-09-22 -4.160363e-02
# 126507            2.864907e+06     NaN   C98USDT  2024-09-23  3.472770e-02
# 126508            5.220245e+06     NaN   C98USDT  2024-09-24  4.195271e-02
# 126509            2.652586e+05     NaN   C98USDT  2024-09-25  1.244510e-02
#
#              reDaily      reDaily7     reDaily30  daily_return  reDaily_scaled
# 0      -2.784919e-02 -6.255356e-02 -1.945159e-01     -0.018750       -0.035613
# 1      -2.688409e-02 -2.071397e-02 -2.148524e-01     -0.027849       -0.035613
# 2      -3.419384e-02  4.189312e-02 -1.886322e-01     -0.026884       -0.035613
# 3      -9.613130e-03  7.033998e-02 -2.808910e-01     -0.034194       -0.035613
# 4       5.397727e-02  1.373106e-01 -2.289299e-01     -0.009613       -0.035613
# ...              ...           ...           ...           ...             ...
# 126505 -4.160363e-02  7.976745e+06  7.976745e+06      0.013027       -0.035613
# 126506  3.472770e-02  7.976745e+06  7.976745e+06     -0.041604       -0.035613
# 126507  4.195271e-02  7.976745e+06  7.976745e+06      0.034728       -0.035613
# 126508  1.244510e-02  1.218107e+07  1.218107e+07      0.041953       -0.035613
# 126509  6.550668e+06  6.550668e+06  6.550668e+06      0.012445        0.308914
#
# [126510 rows x 20 columns]

# %%
# 计算市场的平均回报率（基于 reDaily 列）
market_return = merged_data['reDaily'].mean()

# 计算 Salience Measure (使用 reDaily 和市场平均回报率的差异)
merged_data['salience'] = np.abs(merged_data['reDaily'] - market_return)

# 对 Salience Measure 进行标准化
merged_data['salience_scaled'] = scaler.fit_transform(merged_data[['salience']])

# 输出处理后的数据
print(merged_data[['date', 'daily_return', 'reDaily_scaled', 'salience', 'salience_scaled']].head())
# Out:
#          date  daily_return  reDaily_scaled       salience  salience_scaled
# 0  2023-04-05     -0.018750       -0.035613  677126.361081        -0.032956
# 1  2023-04-06     -0.027849       -0.035613  677126.360116        -0.032956
# 2  2023-04-07     -0.026884       -0.035613  677126.367426        -0.032956
# 3  2023-04-08     -0.034194       -0.035613  677126.342845        -0.032956
# 4  2023-04-09     -0.009613       -0.035613  677126.279255        -0.032956

# %%
merged_data
# Out:
#                        open_time      open      high       low     close  \
# 0       2023-04-05T00:00:00.000Z  0.004807  0.004878  0.004545  0.004668
# 1       2023-04-06T00:00:00.000Z  0.004668  0.004683  0.004465  0.004538
# 2       2023-04-07T00:00:00.000Z  0.004540  0.004570  0.004351  0.004416
# 3       2023-04-08T00:00:00.000Z  0.004416  0.004589  0.004228  0.004265
# 4       2023-04-09T00:00:00.000Z  0.004266  0.004327  0.004087  0.004224
# ...                          ...       ...       ...       ...       ...
# 126505  2024-09-21T00:00:00.000Z  0.130500  0.132700  0.128300  0.132200
# 126506  2024-09-22T00:00:00.000Z  0.132300  0.132300  0.122600  0.126700
# 126507  2024-09-23T00:00:00.000Z  0.126800  0.132100  0.124000  0.131100
# 126508  2024-09-24T00:00:00.000Z  0.131100  0.137600  0.129200  0.136600
# 126509  2024-09-25T00:00:00.000Z  0.136600  0.138500  0.135600  0.138300
#
#               volume    close_time  quote_volume    count  taker_buy_volume  \
# 0       2.345775e+09  1.680739e+12  1.106453e+07  86650.0      1.105395e+09
# 1       1.740994e+09  1.680826e+12  7.900023e+06  68725.0      8.329836e+08
# 2       1.578476e+09  1.680912e+12  6.993093e+06  57472.0      7.815634e+08
# 3       3.125761e+09  1.680998e+12  1.371890e+07  89520.0      1.486423e+09
# 4       2.016344e+09  1.681085e+12  8.474897e+06  73047.0      9.809776e+08
# ...              ...           ...           ...      ...               ...
# 126505  4.512135e+07  1.726963e+12  5.886398e+06  32808.0      2.113208e+07
# 126506  4.706448e+07  1.727050e+12  5.986429e+06  38344.0      2.138675e+07
# 126507  4.465155e+07  1.727136e+12  5.792495e+06  38808.0      2.208139e+07
# 126508  7.888537e+07  1.727222e+12  1.063454e+07  51199.0      3.871896e+07
# 126509  3.313759e+06  1.727309e+12  4.529117e+05   2206.0      1.938562e+06
#
#         ...  futureStk        date           re1       reDaily      reDaily7  \
# 0       ...    CKBUSDT  2023-04-05  2.550818e+08 -2.784919e-02 -6.255356e-02
# 1       ...    CKBUSDT  2023-04-06 -2.784919e-02 -2.688409e-02 -2.071397e-02
# 2       ...    CKBUSDT  2023-04-07 -2.688409e-02 -3.419384e-02  4.189312e-02
# 3       ...    CKBUSDT  2023-04-08 -3.419384e-02 -9.613130e-03  7.033998e-02
# 4       ...    CKBUSDT  2023-04-09 -9.613130e-03  5.397727e-02  1.373106e-01
# ...     ...        ...         ...           ...           ...           ...
# 126505  ...    C98USDT  2024-09-21  1.302682e-02 -4.160363e-02  7.976745e+06
# 126506  ...    C98USDT  2024-09-22 -4.160363e-02  3.472770e-02  7.976745e+06
# 126507  ...    C98USDT  2024-09-23  3.472770e-02  4.195271e-02  7.976745e+06
# 126508  ...    C98USDT  2024-09-24  4.195271e-02  1.244510e-02  1.218107e+07
# 126509  ...    C98USDT  2024-09-25  1.244510e-02  6.550668e+06  6.550668e+06
#
#            reDaily30  daily_return  reDaily_scaled      salience  \
# 0      -1.945159e-01     -0.018750       -0.035613  6.771264e+05
# 1      -2.148524e-01     -0.027849       -0.035613  6.771264e+05
# 2      -1.886322e-01     -0.026884       -0.035613  6.771264e+05
# 3      -2.808910e-01     -0.034194       -0.035613  6.771263e+05
# 4      -2.289299e-01     -0.009613       -0.035613  6.771263e+05
# ...              ...           ...             ...           ...
# 126505  7.976745e+06      0.013027       -0.035613  6.771264e+05
# 126506  7.976745e+06     -0.041604       -0.035613  6.771263e+05
# 126507  7.976745e+06      0.034728       -0.035613  6.771263e+05
# 126508  1.218107e+07      0.041953       -0.035613  6.771263e+05
# 126509  6.550668e+06      0.012445        0.308914  5.873542e+06
#
#         salience_scaled
# 0             -0.032956
# 1             -0.032956
# 2             -0.032956
# 3             -0.032956
# 4             -0.032956
# ...                 ...
# 126505        -0.032956
# 126506        -0.032956
# 126507        -0.032956
# 126508        -0.032956
# 126509         0.240988
#
# [126510 rows x 22 columns]

# %%
print(merged_data.columns)
# Out:
# Index(['open_time', 'open', 'high', 'low', 'close', 'volume', 'close_time',
#        'quote_volume', 'count', 'taker_buy_volume', 'taker_buy_quote_volume',
#        'ignore', 'futureStk', 'date', 're1', 'reDaily', 'reDaily7',
#        'reDaily30', 'daily_return', 'reDaily_scaled', 'salience',
#        'salience_scaled', 'salience_group'],
#       dtype='object')

# %%
import pandas as pd
import numpy as np

# 假设 'merged_data' 数据集已经包含 'salience' 和 'reDaily' 列（已经计算完成）

# 1. 按 Salience Measure 分组（五分位数分组）
merged_data['salience_group'] = pd.qcut(merged_data['salience'], 5, labels=False) + 1  # 五分位数分组，标记为1到5

# 2. 计算等权重组合的回报率
# 先按照日期进行分组，计算每个分组内的等权重回报率
equal_weight_return = merged_data.groupby(['date', 'salience_group'])['reDaily'].mean().reset_index()

# 使用 pivot 函数将数据转换为按日期和组别显示的格式
equal_weight_return = equal_weight_return.pivot(index='date', columns='salience_group', values='reDaily')

# 3. 生成 Salience 高低组合差策略
# 等权重组合的 Salience 高低组合差
equal_weight_return['High-Low'] = equal_weight_return[5] - equal_weight_return[1]

# 4. 输出结果
print("Equal Weight Return (Top 5 Group - Bottom 1 Group):")
print(equal_weight_return[['High-Low']].head())
# Out:
# Equal Weight Return (Top 5 Group - Bottom 1 Group):
# salience_group      High-Low
# date
# 2023-04-05      3.001827e+06
# 2023-04-06      1.397708e+07
# 2023-04-07      1.771257e+07
# 2023-04-08      5.067845e+06
# 2023-04-09      7.094983e+06

# %%
import statsmodels.api as sm

# 构建回归模型数据，假设 Salience 和 daily_return 已经计算完成
# 我们将 Salience 作为自变量，reDaily 作为因变量
X = merged_data['salience']
y = merged_data['reDaily']

# 添加常数项
X = sm.add_constant(X)

# OLS 回归模型
model = sm.OLS(y, X)
results = model.fit()

# 输出回归结果
print(results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                reDaily   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                  1.000
# Method:                 Least Squares   F-statistic:                 6.944e+08
# Date:                Mon, 14 Oct 2024   Prob (F-statistic):               0.00
# Time:                        16:28:39   Log-Likelihood:            -1.7552e+06
# No. Observations:              126510   AIC:                         3.510e+06
# Df Residuals:                  126508   BIC:                         3.510e+06
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -6.281e+05    723.184   -868.507      0.000    -6.3e+05   -6.27e+05
# salience       1.0023    3.8e-05   2.64e+04      0.000       1.002       1.002
# ==============================================================================
# Omnibus:                   115588.231   Durbin-Watson:                   0.318
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          3435891.945
# Skew:                           4.578   Prob(JB):                         0.00
# Kurtosis:                      26.832   Cond. No.                     1.91e+07
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.91e+07. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
# 构建包含多个自变量的回归模型
X_multi = merged_data[['salience', 'volume', 'quote_volume']]  # 假设我们使用 'volume' 和 'quote_volume' 作为其他因子
X_multi = sm.add_constant(X_multi)
y = merged_data['reDaily']

# OLS 回归模型
model_multi = sm.OLS(y, X_multi)
results_multi = model_multi.fit()

# 输出回归结果
print(results_multi.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                reDaily   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                  1.000
# Method:                 Least Squares   F-statistic:                 2.317e+08
# Date:                Mon, 14 Oct 2024   Prob (F-statistic):               0.00
# Time:                        16:28:57   Log-Likelihood:            -1.7552e+06
# No. Observations:              126510   AIC:                         3.510e+06
# Df Residuals:                  126506   BIC:                         3.510e+06
# Df Model:                           3
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const        -6.268e+05    732.133   -856.190      0.000   -6.28e+05   -6.25e+05
# salience         1.0023    3.8e-05   2.64e+04      0.000       1.002       1.002
# volume       -5.767e-08   1.25e-08     -4.632      0.000   -8.21e-08   -3.33e-08
# quote_volume -5.802e-06   6.07e-07     -9.560      0.000   -6.99e-06   -4.61e-06
# ==============================================================================
# Omnibus:                   115469.477   Durbin-Watson:                   0.319
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          3422689.808
# Skew:                           4.572   Prob(JB):                         0.00
# Kurtosis:                      26.785   Cond. No.                     5.90e+10
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 5.9e+10. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
import numpy as np

# 构建回归模型的数据
# 我们假设 Salience 作为自变量，reDaily 作为因变量
fama_macbeth_coefficients = []

# 对每个日期分组，进行横截面回归
for date, group in merged_data.groupby('date'):
    X = group['salience']
    y = group['reDaily']
    
    # 添加常数项
    X = sm.add_constant(X)
    
    # OLS 回归模型
    model = sm.OLS(y, X)
    results = model.fit()
    
    # 保存每个日期的回归系数
    fama_macbeth_coefficients.append(results.params)

# 计算时间维度上的平均回归系数
fama_macbeth_coefficients = np.array(fama_macbeth_coefficients)
average_coefficients = fama_macbeth_coefficients.mean(axis=0)

# 输出结果
print("Fama-MacBeth 平均回归系数:")
print(average_coefficients)
# Out:
# Fama-MacBeth 平均回归系数:
# [-7.59691655e+05  1.13865440e+00]

# %%
# 使用整个数据集进行回归
X_full = merged_data['salience']
y_full = merged_data['reDaily']

# 添加常数项
X_full = sm.add_constant(X_full)

# OLS 回归模型
model_full = sm.OLS(y_full, X_full)
results_full = model_full.fit()

# 绘图
plt.figure(figsize=(10, 6))
plt.plot(merged_data['salience'], merged_data['reDaily'], 'o', label="Data Points")
plt.plot(merged_data['salience'], results_full.predict(X_full), label="Fitted Line", color="red")
plt.xlabel('Salience Measure')
plt.ylabel('Daily Return')
plt.title('Regression of Salience Measure on Daily Return')
plt.legend()
plt.show()

# %%
import pandas as pd

# 提取回归模型的结果
regression_summary = pd.DataFrame({
    'Coefficient': results_full.params,
    't-Value': results_full.tvalues,
    'P-Value': results_full.pvalues,
    '95% CI Lower': results_full.conf_int()[0],
    '95% CI Upper': results_full.conf_int()[1]
})

# 打印回归结果表格
print("回归分析统计表：")
print(regression_summary)

# 如果需要保存到文件：
regression_summary.to_csv('regression_summary.csv', index=True)
# Out:
# 回归分析统计表：
#             Coefficient       t-Value  P-Value   95% CI Lower   95% CI Upper
# const    -628090.728534   -868.507060      0.0 -629508.157409 -626673.299660
# salience       1.002263  26350.843876      0.0       1.002188       1.002337

# %%
import matplotlib.pyplot as plt

# 绘制 Salience Measure 与 Daily Return 关系图
plt.figure(figsize=(10, 6))
plt.plot(merged_data['salience'], merged_data['reDaily'], 'o', label="Data Points")
plt.plot(merged_data['salience'], results_full.predict(X_full), label="Fitted Line", color="red")
plt.xlabel('Salience Measure')
plt.ylabel('Daily Return')
plt.title('Regression of Salience Measure on Daily Return')
plt.legend()
plt.show()

# %%
# 确保 high 和 low 组都存在，并计算高低组合差策略
high_returns = merged_data[merged_data['salience_group'] == 5]['reDaily']
low_returns = merged_data[merged_data['salience_group'] == 1]['reDaily']

# 计算高低组合差策略的每日回报率，排除缺失值
high_low_diff_returns = high_returns.subtract(low_returns, fill_value=0)

# 如果高低组合差返回全为0，确保有数据可用
if high_low_diff_returns.isna().all():
    print("高低组合差策略中缺少有效数据。请检查数据分组。")
else:
    # 计算 Salience 高低组合差策略的年化回报率、夏普比率等
    def calculate_statistics(returns):
        annual_return = returns.mean() * 252
        annual_volatility = returns.std() * np.sqrt(252)
        sharpe_ratio = annual_return / annual_volatility if annual_volatility != 0 else np.nan
        return {
            'Annual Return': annual_return,
            'Annual Volatility': annual_volatility,
            'Sharpe Ratio': sharpe_ratio
        }

    # 计算高低组合差策略的统计结果
    stats_high_low_diff = calculate_statistics(high_low_diff_returns.dropna())

    # 打印统计结果
    stats_df = pd.DataFrame([stats_high_low_diff], index=['High-Low Strategy'])
    print("Salience 高低组合差策略统计表：")
    print(stats_df)

    # 如果需要保存到文件
    stats_df.to_csv('high_low_diff_stats.csv', index=True)
# Out:
# Salience 高低组合差策略统计表：
#                    Annual Return  Annual Volatility  Sharpe Ratio
# High-Low Strategy   4.265896e+08       4.767856e+08       0.89472

# %%
# 绘制残差图
plt.figure(figsize=(10, 6))
plt.scatter(results_full.predict(X_full), results_full.resid)
plt.axhline(y=0, color='r', linestyle='--')
plt.xlabel('Fitted Values')
plt.ylabel('Residuals')
plt.title('Residual Plot')
plt.show()

# %%
# 确保日期和回报数据匹配
dates = merged_data[merged_data['salience_group'] == 5]['date'].reset_index(drop=True)  # 使用高组合的日期
high_low_diff_cumulative_return = (1 + high_low_diff_returns).cumprod().reset_index(drop=True)

# 确保日期和累积回报的长度一致
if len(dates) != len(high_low_diff_cumulative_return):
    min_len = min(len(dates), len(high_low_diff_cumulative_return))
    dates = dates[:min_len]
    high_low_diff_cumulative_return = high_low_diff_cumulative_return[:min_len]

# 绘制累积回报图
plt.figure(figsize=(10, 6))
plt.plot(dates, high_low_diff_cumulative_return, label='High-Low Strategy Cumulative Return')
plt.xlabel('Date')
plt.ylabel('Cumulative Return')
plt.title('Salience High-Low Strategy Cumulative Return Over Time')
plt.legend()
plt.show()
# Out:
# /opt/anaconda3/envs/pythonProject/lib/python3.8/site-packages/numpy/core/fromnumeric.py:57: RuntimeWarning: overflow encountered in accumulate
#   return bound(*args, **kwds)
